# %% [markdown]
# <a href="https://colab.research.google.com/github/khagerthey/VIS1/blob/main/FinalP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time, os, sys, re
import zipfile, json, datetime, string
import numpy as np
from statistics import *

import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as pdr
from pandas_datareader import wb
from pandas.io.formats.style import Styler

import plotly as py

import plotly.graph_objects as go

import urllib

from google.colab import files

import webbrowser
import folium as f
from folium.plugins import MarkerCluster, HeatMap

import seaborn as sns

from google.colab import data_table
data_table.enable_dataframe_formatter()

# %matplotlib inline
# %matplotlib
#%matplotlib --list
#interactive plots:
# %matplotlib notebook
#static images of your plot:
# %matplotlib inline
#may play with this one and other magics (btw default is probably agg)
# %matplotlib nbagg

import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px

from matplotlib.sankey import Sankey
# %matplotlib inline

###themes/styles: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#https://jakevdp.github.io/PythonDataScienceHandbook/04.11-settings-and-stylesheets.html
#https://matplotlib.org/stable/tutorials/introductory/customizing.html
#here more about art and style than under the hood functionality as with magics, explore and experiment
#many may find 'default' or seaborn ones more pleasing; my fav 'classic' is back from 90s ;)
plt.style.available #list available styles :) may install more
plt.style.use('default') # more delicate subtle than classic
plt.style.use('classic')  #  'seaborn-whitegrid' 'seaborn-white' 'seaborn-poster'
# btw: magics v theme/style sequence matters, eg if i specify classic style before inline magic, i wouldnt get grey bounding box im getting
# Out:
# Using matplotlib backend: nbAgg
# Warning: Cannot change to a different GUI toolkit: nbagg. Using notebook instead.

# %% [markdown]
# #**Hypothesis:**
# Line 3 is experiencing high amounts of glass breakages. The cause of breakages is believed by management to be due to thermal shock. I believe this is actually not true and this idea is primarily stemed from a lack of documentation. Breakages are likely a mix of issues due to impact from the line, human error, lack of training, and thermal shock.
#
# This food production company is currently investigating a high amount of glass breakages on their highest performing production line (3). Data recieved from said company is confidential, I am not premitted to link or post directly from source. All private information (including company name) has been removed.

# %% [markdown]
# ##First Data Collection Attempt

# %%
Start=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/Line%203%20bottle%20count%20record%20.xlsx%20-%20START%20(1).csv')
Start.dropna(axis = 0, how = 'all')
#Start = Start.rename(columns={'Unnamed: 0':'Location'})
#NaN is okay, data not expected to be there
Start
# Out:
#           DAY  DEPALLETIZER   FILLER   CAPPER  DUD DETECTOR  LABELER   \
# 0  FEBUARY 27          39167    39165   38771         38402     33864
# 1  FEBUARY 28           1990     1251    1245          1226      8296
# 2     March 1         140529   140450  138020        134007    139700
# 3     March 2         113923   113031  111134         82622    112333
# 4     March 6         120721   120643  118643        117599    120109
# 5     March 7         120079   120042  118307        114180    119908
# 6     March 8            200       76      75            86         0
#
#    TRAYMAKER
# 0      33684
# 1       3264
# 2     136980
# 3     112080
# 4     119556
# 5     119508
# 6         84

# %%
print(Start.sum())
# Out:
# DAY              FEBUARY 27FEBUARY 28March 1March 2March 6March...
# DEPALLETIZER                                                536609
# FILLER                                                      534658
# CAPPER                                                      526195
# DUD DETECTOR                                                488122
# LABELER                                                     534210
# TRAYMAKER                                                   525156
# dtype: object

# %%
Loss=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/Line%203%20bottle%20count%20record%20.xlsx%20-%20LOSS%20(1).csv')
Loss
# Out:
#           DAY  DEPALLETIZER TO FILLER  FILLER TO CAPPER  \
# 0  FEBUARY 27                       2               394
# 1  FEBUARY 28                     739                 6
# 2     March 1                      79              2430
# 3     March 2                     892              1897
# 4     March 6                      78              2000
# 5     March 7                      37              1735
# 6     March 8                     124                 1
#
#    CAPPER TO DUD DETECTOR  DUD DETECTOR TO LABELER  LABELER TO TRAYMAKER
# 0                     369                     4538                   180
# 1                      19                    -7070                  5032
# 2                    4013                    -5693                  2720
# 3                   28512                   -29711                   253
# 4                    1044                    -2510                   553
# 5                    4127                    -5728                   400
# 6                     -11                       86                   -84

# %%
print(Loss.sum())
# Out:
# DAY                        FEBUARY 27FEBUARY 28March 1March 2March 6March...
# DEPALLETIZER TO FILLER                                                  1951
# FILLER TO CAPPER                                                        8463
# CAPPER TO DUD DETECTOR                                                 38073
# DUD DETECTOR TO LABELER                                               -46088
# LABELER TO TRAYMAKER                                                    9054
# dtype: object

# %% [markdown]
# Why are there negatives at the dud detector to the labeler? Negatives imply a gain in glass. Must be further investigated.

# %%
Totalloss = pd.merge(Loss, Start, how='outer', on=['DAY'], indicator='there')
Totalloss
# Out:
#           DAY  DEPALLETIZER TO FILLER  FILLER TO CAPPER  \
# 0  FEBUARY 27                       2               394
# 1  FEBUARY 28                     739                 6
# 2     March 1                      79              2430
# 3     March 2                     892              1897
# 4     March 6                      78              2000
# 5     March 7                      37              1735
# 6     March 8                     124                 1
#
#    CAPPER TO DUD DETECTOR  DUD DETECTOR TO LABELER  LABELER TO TRAYMAKER  \
# 0                     369                     4538                   180
# 1                      19                    -7070                  5032
# 2                    4013                    -5693                  2720
# 3                   28512                   -29711                   253
# 4                    1044                    -2510                   553
# 5                    4127                    -5728                   400
# 6                     -11                       86                   -84
#
#    DEPALLETIZER   FILLER   CAPPER  DUD DETECTOR  LABELER   TRAYMAKER there
# 0          39167    39165   38771         38402     33864      33684  both
# 1           1990     1251    1245          1226      8296       3264  both
# 2         140529   140450  138020        134007    139700     136980  both
# 3         113923   113031  111134         82622    112333     112080  both
# 4         120721   120643  118643        117599    120109     119556  both
# 5         120079   120042  118307        114180    119908     119508  both
# 6            200       76      75            86         0         84  both

# %%
Totalloss.there.value_counts(sort=False)
#Okay, same data from before not expected to merge
# Out:
# there
# left_only     0
# right_only    0
# both          7
# Name: count, dtype: int64

# %%
Totalloss = pd.merge(Loss, Start, how='inner', on=['DAY'], indicator='there')
Totalloss
# Out:
#           DAY  DEPALLETIZER TO FILLER  FILLER TO CAPPER  \
# 0  FEBUARY 27                       2               394
# 1  FEBUARY 28                     739                 6
# 2     March 1                      79              2430
# 3     March 2                     892              1897
# 4     March 6                      78              2000
# 5     March 7                      37              1735
# 6     March 8                     124                 1
#
#    CAPPER TO DUD DETECTOR  DUD DETECTOR TO LABELER  LABELER TO TRAYMAKER  \
# 0                     369                     4538                   180
# 1                      19                    -7070                  5032
# 2                    4013                    -5693                  2720
# 3                   28512                   -29711                   253
# 4                    1044                    -2510                   553
# 5                    4127                    -5728                   400
# 6                     -11                       86                   -84
#
#    DEPALLETIZER   FILLER   CAPPER  DUD DETECTOR  LABELER   TRAYMAKER there
# 0          39167    39165   38771         38402     33864      33684  both
# 1           1990     1251    1245          1226      8296       3264  both
# 2         140529   140450  138020        134007    139700     136980  both
# 3         113923   113031  111134         82622    112333     112080  both
# 4         120721   120643  118643        117599    120109     119556  both
# 5         120079   120042  118307        114180    119908     119508  both
# 6            200       76      75            86         0         84  both

# %%
TL = Totalloss[['DAY', 'DEPALLETIZER ', 'DEPALLETIZER TO FILLER', 'FILLER ', 'FILLER TO CAPPER', 'CAPPER', 'CAPPER TO DUD DETECTOR', 'DUD DETECTOR', 'DUD DETECTOR TO LABELER', 'LABELER ', 'LABELER TO TRAYMAKER', 'TRAYMAKER']]

TL
#columns reordered for clearer comparision
# Out:
#           DAY  DEPALLETIZER   DEPALLETIZER TO FILLER  FILLER   \
# 0  FEBUARY 27          39167                       2    39165
# 1  FEBUARY 28           1990                     739     1251
# 2     March 1         140529                      79   140450
# 3     March 2         113923                     892   113031
# 4     March 6         120721                      78   120643
# 5     March 7         120079                      37   120042
# 6     March 8            200                     124       76
#
#    FILLER TO CAPPER  CAPPER  CAPPER TO DUD DETECTOR  DUD DETECTOR  \
# 0               394   38771                     369         38402
# 1                 6    1245                      19          1226
# 2              2430  138020                    4013        134007
# 3              1897  111134                   28512         82622
# 4              2000  118643                    1044        117599
# 5              1735  118307                    4127        114180
# 6                 1      75                     -11            86
#
#    DUD DETECTOR TO LABELER  LABELER   LABELER TO TRAYMAKER  TRAYMAKER
# 0                     4538     33864                   180      33684
# 1                    -7070      8296                  5032       3264
# 2                    -5693    139700                  2720     136980
# 3                   -29711    112333                   253     112080
# 4                    -2510    120109                   553     119556
# 5                    -5728    119908                   400     119508
# 6                       86         0                   -84         84

# %% [markdown]
# This first round of data collection showed miscalculations. Negatives imply glass was added back onto the line, this is not possible as the areas are after the filler and therefore would not have product in them. Management has concluded that the negatives imply that the line was being used for "rework" (a process in which finished goods are placed back on the line for adjustments such as relabeling). Negatives were addressed to management to which they recalibrated the machine and moved rework to other lines not in use to maintain moree usable data.

# %% [markdown]
# #More Investigating

# %% [markdown]
# ###The negative amounts lead for inaccurate results. Below are the recorded amounts after the machine had been recalibrated and rework had been relocated.

# %%
NewStart=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/Line%203%20bottle%20count%20record%20.xlsx%20-%20NEW%20START%20(2).csv')
NewStart
# Out:
#          DAY  DEPALLETIZER   FILLER   CAPPER  DUD DETECTOR  LABELER   \
# 0   March 16          14728    14710   12951          7913      7857
# 1   March 20          18464    18400   15858          7359      6975
# 2   March 21          37347    37328   36375         29665     29471
# 3   March 22          37452    37428   36437         34321     34068
# 4   March 23         100423   100117   97264         91731     91617
# 5   March 27          75997    75709   73937         70185     70096
# 6   March 28          25476    25384   25302         17868     17762
# 7   March 29         122140   122078  121863        112672    102387
# 8    April 3         136292   136242  136162        126619    125726
# 9    April 4         135137   135081  134894        133917    132813
# 10   April 5         146042   145991  145692        143915    143615
# 11   April 6        1037686  1016153  971138        926360    925852
# 12  April 11         146283   146207  145956        137550    136757
# 13  April 12         122641   122583  122387        112754    112334
#
#     TRAYMAKER
# 0        7127
# 1        6322
# 2       29368
# 3       33736
# 4       90858
# 5       69362
# 6       17640
# 7       91918
# 8      124902
# 9      130112
# 10     143472
# 11     923006
# 12     135670
# 13     110326

# %%
print(NewStart.sum())
# Out:
# DAY              March 16March 20March 21March 22March 23March ...
# DEPALLETIZER                                               2156108
# FILLER                                                     2133411
# CAPPER                                                     2076216
# DUD DETECTOR                                               1952829
# LABELER                                                    1937330
# TRAYMAKER                                                  1913819
# dtype: object

# %%
NewLoss=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/Line%203%20bottle%20count%20record%20.xlsx%20-%20NEW%20LOSS%20(3).csv')
NewLoss
# Out:
#          DAY  DEPALLETIZER TO FILLER  FILLER TO CAPPER  \
# 0   March 16                      18              1759
# 1   March 20                      64              2542
# 2   March 21                      19               953
# 3   March 22                      24               991
# 4   March 23                     306              2853
# 5   March 27                     288              1772
# 6   March 28                      92                82
# 7   March 29                      62               215
# 8    April 3                      50                80
# 9    April 4                      56               187
# 10   April 5                      51               299
# 11   April 6                   21533             45015
# 12  April 11                      76               251
# 13  April 12                      58               196
#
#     CAPPER TO DUD DETECTOR  DUD DETECTOR TO LABELER  LABELER TO TRAYMAKER  \
# 0                     5038                       56                   730
# 1                     8499                      384                   653
# 2                     6710                      194                   103
# 3                     2116                      253                   332
# 4                     5533                      114                   759
# 5                     3752                       89                   734
# 6                     7434                      106                   122
# 7                     9191                    10285                 10469
# 8                     9543                      893                   824
# 9                      977                     1104                  2701
# 10                    1777                      300                   143
# 11                   44778                      508                  2846
# 12                    8406                      793                  1087
# 13                    9633                      420                  2008
#
#        SUM
# 0     7601
# 1    12142
# 2     7979
# 3     3716
# 4     9565
# 5     6635
# 6     7836
# 7    30222
# 8    11390
# 9     5025
# 10    2570
# 11  114680
# 12   10613
# 13   12315

# %%
print(NewLoss.sum())
# Out:
# DAY                        March 16March 20March 21March 22March 23March ...
# DEPALLETIZER TO FILLER                                                 22697
# FILLER TO CAPPER                                                       57195
# CAPPER TO DUD DETECTOR                                                123387
# DUD DETECTOR TO LABELER                                                15499
# LABELER TO TRAYMAKER                                                   23511
# SUM                                                                   242289
# dtype: object

# %% [markdown]
# The recalibrated data now shows the high breakage areas as filler to capper, dud detector to labeler, and labeler to traymaker.

# %%
NewTotalloss = pd.merge(NewLoss, NewStart, how='outer', on=['DAY'], indicator='true')
NewTotalloss
# Out:
#          DAY  DEPALLETIZER TO FILLER  FILLER TO CAPPER  \
# 0   March 16                      18              1759
# 1   March 20                      64              2542
# 2   March 21                      19               953
# 3   March 22                      24               991
# 4   March 23                     306              2853
# 5   March 27                     288              1772
# 6   March 28                      92                82
# 7   March 29                      62               215
# 8    April 3                      50                80
# 9    April 4                      56               187
# 10   April 5                      51               299
# 11   April 6                   21533             45015
# 12  April 11                      76               251
# 13  April 12                      58               196
#
#     CAPPER TO DUD DETECTOR  DUD DETECTOR TO LABELER  LABELER TO TRAYMAKER  \
# 0                     5038                       56                   730
# 1                     8499                      384                   653
# 2                     6710                      194                   103
# 3                     2116                      253                   332
# 4                     5533                      114                   759
# 5                     3752                       89                   734
# 6                     7434                      106                   122
# 7                     9191                    10285                 10469
# 8                     9543                      893                   824
# 9                      977                     1104                  2701
# 10                    1777                      300                   143
# 11                   44778                      508                  2846
# 12                    8406                      793                  1087
# 13                    9633                      420                  2008
#
#        SUM  DEPALLETIZER   FILLER   CAPPER  DUD DETECTOR  LABELER   TRAYMAKER  \
# 0     7601          14728    14710   12951          7913      7857       7127
# 1    12142          18464    18400   15858          7359      6975       6322
# 2     7979          37347    37328   36375         29665     29471      29368
# 3     3716          37452    37428   36437         34321     34068      33736
# 4     9565         100423   100117   97264         91731     91617      90858
# 5     6635          75997    75709   73937         70185     70096      69362
# 6     7836          25476    25384   25302         17868     17762      17640
# 7    30222         122140   122078  121863        112672    102387      91918
# 8    11390         136292   136242  136162        126619    125726     124902
# 9     5025         135137   135081  134894        133917    132813     130112
# 10    2570         146042   145991  145692        143915    143615     143472
# 11  114680        1037686  1016153  971138        926360    925852     923006
# 12   10613         146283   146207  145956        137550    136757     135670
# 13   12315         122641   122583  122387        112754    112334     110326
#
#     true
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both
# 5   both
# 6   both
# 7   both
# 8   both
# 9   both
# 10  both
# 11  both
# 12  both
# 13  both

# %%
NewTotalloss.true.value_counts(sort=False)
# Out:
# true
# left_only      0
# right_only     0
# both          14
# Name: count, dtype: int64

# %% [markdown]
# ##Merged Total

# %%
NTL = NewTotalloss[['DAY', 'DEPALLETIZER ', 'DEPALLETIZER TO FILLER', 'FILLER ', 'FILLER TO CAPPER', 'CAPPER', 'CAPPER TO DUD DETECTOR', 'DUD DETECTOR', 'DUD DETECTOR TO LABELER', 'LABELER ', 'LABELER TO TRAYMAKER', 'TRAYMAKER']]

NTL
#Total counts for a month's time
# Out:
#          DAY  DEPALLETIZER   DEPALLETIZER TO FILLER  FILLER   \
# 0   March 16          14728                      18    14710
# 1   March 20          18464                      64    18400
# 2   March 21          37347                      19    37328
# 3   March 22          37452                      24    37428
# 4   March 23         100423                     306   100117
# 5   March 27          75997                     288    75709
# 6   March 28          25476                      92    25384
# 7   March 29         122140                      62   122078
# 8    April 3         136292                      50   136242
# 9    April 4         135137                      56   135081
# 10   April 5         146042                      51   145991
# 11   April 6        1037686                   21533  1016153
# 12  April 11         146283                      76   146207
# 13  April 12         122641                      58   122583
#
#     FILLER TO CAPPER  CAPPER  CAPPER TO DUD DETECTOR  DUD DETECTOR  \
# 0               1759   12951                    5038          7913
# 1               2542   15858                    8499          7359
# 2                953   36375                    6710         29665
# 3                991   36437                    2116         34321
# 4               2853   97264                    5533         91731
# 5               1772   73937                    3752         70185
# 6                 82   25302                    7434         17868
# 7                215  121863                    9191        112672
# 8                 80  136162                    9543        126619
# 9                187  134894                     977        133917
# 10               299  145692                    1777        143915
# 11             45015  971138                   44778        926360
# 12               251  145956                    8406        137550
# 13               196  122387                    9633        112754
#
#     DUD DETECTOR TO LABELER  LABELER   LABELER TO TRAYMAKER  TRAYMAKER
# 0                        56      7857                   730       7127
# 1                       384      6975                   653       6322
# 2                       194     29471                   103      29368
# 3                       253     34068                   332      33736
# 4                       114     91617                   759      90858
# 5                        89     70096                   734      69362
# 6                       106     17762                   122      17640
# 7                     10285    102387                 10469      91918
# 8                       893    125726                   824     124902
# 9                      1104    132813                  2701     130112
# 10                      300    143615                   143     143472
# 11                      508    925852                  2846     923006
# 12                      793    136757                  1087     135670
# 13                      420    112334                  2008     110326

# %%
NTL.dtypes
# Out:
# DAY                        object
# DEPALLETIZER                int64
# DEPALLETIZER TO FILLER      int64
# FILLER                      int64
# FILLER TO CAPPER            int64
# CAPPER                      int64
# CAPPER TO DUD DETECTOR      int64
# DUD DETECTOR                int64
# DUD DETECTOR TO LABELER     int64
# LABELER                     int64
# LABELER TO TRAYMAKER        int64
# TRAYMAKER                   int64
# dtype: object

# %%
#Percentage of breakages recorded in each area for the day
NTL['totLos']=NTL['DEPALLETIZER TO FILLER']+NTL['FILLER TO CAPPER']+NTL['CAPPER TO DUD DETECTOR']+NTL['DUD DETECTOR TO LABELER']+NTL['LABELER TO TRAYMAKER']
NTL['DEPALLETIZER TO FILLER']=100*(NTL['DEPALLETIZER TO FILLER']/NTL['totLos'])
NTL['FILLER TO CAPPER']=100*(NTL['FILLER TO CAPPER']/NTL['totLos'])
NTL['CAPPER TO DUD DETECTOR']=100*(NTL['CAPPER TO DUD DETECTOR']/NTL['totLos'])
NTL['DUD DETECTOR TO LABELER']=100*(NTL['DUD DETECTOR TO LABELER']/NTL['totLos'])
NTL['LABELER TO TRAYMAKER']=100*(NTL['LABELER TO TRAYMAKER']/NTL['totLos'])
NTL
# Out:
# <ipython-input-74-ec1e2a881e4c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-74-ec1e2a881e4c>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-74-ec1e2a881e4c>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-74-ec1e2a881e4c>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-74-ec1e2a881e4c>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-74-ec1e2a881e4c>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          DAY  DEPALLETIZER   DEPALLETIZER TO FILLER  FILLER   \
# 0   March 16          14728                0.236811    14710
# 1   March 20          18464                0.527096    18400
# 2   March 21          37347                0.238125    37328
# 3   March 22          37452                0.645856    37428
# 4   March 23         100423                3.199164   100117
# 5   March 27          75997                4.340618    75709
# 6   March 28          25476                1.174068    25384
# 7   March 29         122140                0.205149   122078
# 8    April 3         136292                0.438982   136242
# 9    April 4         135137                1.114428   135081
# 10   April 5         146042                1.984436   145991
# 11   April 6        1037686               18.776596  1016153
# 12  April 11         146283                0.716103   146207
# 13  April 12         122641                0.470970   122583
#
#     FILLER TO CAPPER  CAPPER  CAPPER TO DUD DETECTOR  DUD DETECTOR  \
# 0          23.141692   12951               66.280753          7913
# 1          20.935595   15858               69.996706          7359
# 2          11.943853   36375               84.095751         29665
# 3          26.668461   36437               56.942949         34321
# 4          29.827496   97264               57.846315         91731
# 5          26.706858   73937               56.548606         70185
# 6           1.046452   25302               94.869832         17868
# 7           0.711402  121863               30.411621        112672
# 8           0.702371  136162               83.784021        126619
# 9           3.721393  134894               19.442786        133917
# 10         11.634241  145692               69.143969        143915
# 11         39.252703  971138               39.046041        926360
# 12          2.365024  145956               79.204749        137550
# 13          1.591555  122387               78.221681        112754
#
#     DUD DETECTOR TO LABELER  LABELER   LABELER TO TRAYMAKER  TRAYMAKER  totLos
# 0                  0.736745      7857              9.603999       7127    7601
# 1                  3.162576      6975              5.378027       6322   12142
# 2                  2.431382     29471              1.290889      29368    7979
# 3                  6.808396     34068              8.934338      33736    3716
# 4                  1.191845     91617              7.935180      90858    9565
# 5                  1.341372     70096             11.062547      69362    6635
# 6                  1.352731     17762              1.556917      17640    7836
# 7                 34.031500    102387             34.640328      91918   30222
# 8                  7.840211    125726              7.234416     124902   11390
# 9                 21.970149    132813             53.751244     130112    5025
# 10                11.673152    143615              5.564202     143472    2570
# 11                 0.442972    925852              2.481688     923006  114680
# 12                 7.471968    136757             10.242156     135670   10613
# 13                 3.410475    112334             16.305319     110326   12315

# %%
NTL_print=NTL[[ 'DEPALLETIZER TO FILLER', 'FILLER TO CAPPER', 'CAPPER TO DUD DETECTOR', 'DUD DETECTOR TO LABELER', 'LABELER TO TRAYMAKER']]
NTL_print['DEPALLETIZER TO FILLER']=NTL_print['DEPALLETIZER TO FILLER'].astype(float).round(2)
NTL_print['FILLER TO CAPPER']=NTL_print['FILLER TO CAPPER'].astype(float).round(2)
NTL_print['CAPPER TO DUD DETECTOR']=NTL_print['CAPPER TO DUD DETECTOR'].astype(float).round(2)
NTL_print['DUD DETECTOR TO LABELER']=NTL_print['DUD DETECTOR TO LABELER'].astype(float).round(2)
NTL_print['LABELER TO TRAYMAKER']=NTL_print['LABELER TO TRAYMAKER'].astype(float).round(2)
#calculating percatages of breakage using python
# Out:
# <ipython-input-75-95da8a9df5e0>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-95da8a9df5e0>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-95da8a9df5e0>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-95da8a9df5e0>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-95da8a9df5e0>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
NTL_print.style.format(precision=2).background_gradient(cmap = 'Blues')
#Percentage of breakages recorded in each area for the day
#Gradient applied to make large loss more visable
# Out:
# <style type="text/css">
# #T_21d43_row0_col0, #T_21d43_row2_col0, #T_21d43_row2_col4, #T_21d43_row7_col0, #T_21d43_row7_col1, #T_21d43_row8_col1, #T_21d43_row9_col2, #T_21d43_row11_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_21d43_row0_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_21d43_row0_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_21d43_row0_col3, #T_21d43_row6_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_21d43_row0_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_21d43_row1_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_21d43_row1_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_21d43_row1_col2 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_21d43_row1_col3, #T_21d43_row9_col1, #T_21d43_row10_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_21d43_row1_col4 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_21d43_row2_col1 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_21d43_row2_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_21d43_row2_col3 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_21d43_row3_col0, #T_21d43_row5_col3, #T_21d43_row6_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_21d43_row3_col1, #T_21d43_row5_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_21d43_row3_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_21d43_row3_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_21d43_row3_col4, #T_21d43_row7_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_21d43_row4_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_21d43_row4_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_21d43_row4_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_21d43_row4_col3, #T_21d43_row11_col4, #T_21d43_row13_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_21d43_row4_col4 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_21d43_row5_col0, #T_21d43_row8_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_21d43_row5_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_21d43_row5_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_21d43_row6_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_21d43_row6_col2, #T_21d43_row7_col3, #T_21d43_row9_col4, #T_21d43_row11_col0, #T_21d43_row11_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_21d43_row6_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_21d43_row7_col4 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_21d43_row8_col0, #T_21d43_row13_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_21d43_row8_col2 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_21d43_row8_col4 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_21d43_row9_col0, #T_21d43_row12_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_21d43_row9_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_21d43_row10_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_21d43_row10_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_21d43_row10_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_21d43_row10_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_21d43_row11_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_21d43_row12_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_21d43_row12_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_21d43_row12_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_21d43_row12_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_21d43_row13_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_21d43_row13_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_21d43_row13_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# </style>
# <table id="T_21d43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21d43_level0_col0" class="col_heading level0 col0" >DEPALLETIZER TO FILLER</th>
#       <th id="T_21d43_level0_col1" class="col_heading level0 col1" >FILLER TO CAPPER</th>
#       <th id="T_21d43_level0_col2" class="col_heading level0 col2" >CAPPER TO DUD DETECTOR</th>
#       <th id="T_21d43_level0_col3" class="col_heading level0 col3" >DUD DETECTOR TO LABELER</th>
#       <th id="T_21d43_level0_col4" class="col_heading level0 col4" >LABELER TO TRAYMAKER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21d43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21d43_row0_col0" class="data row0 col0" >0.24</td>
#       <td id="T_21d43_row0_col1" class="data row0 col1" >23.14</td>
#       <td id="T_21d43_row0_col2" class="data row0 col2" >66.28</td>
#       <td id="T_21d43_row0_col3" class="data row0 col3" >0.74</td>
#       <td id="T_21d43_row0_col4" class="data row0 col4" >9.60</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21d43_row1_col0" class="data row1 col0" >0.53</td>
#       <td id="T_21d43_row1_col1" class="data row1 col1" >20.94</td>
#       <td id="T_21d43_row1_col2" class="data row1 col2" >70.00</td>
#       <td id="T_21d43_row1_col3" class="data row1 col3" >3.16</td>
#       <td id="T_21d43_row1_col4" class="data row1 col4" >5.38</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21d43_row2_col0" class="data row2 col0" >0.24</td>
#       <td id="T_21d43_row2_col1" class="data row2 col1" >11.94</td>
#       <td id="T_21d43_row2_col2" class="data row2 col2" >84.10</td>
#       <td id="T_21d43_row2_col3" class="data row2 col3" >2.43</td>
#       <td id="T_21d43_row2_col4" class="data row2 col4" >1.29</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21d43_row3_col0" class="data row3 col0" >0.65</td>
#       <td id="T_21d43_row3_col1" class="data row3 col1" >26.67</td>
#       <td id="T_21d43_row3_col2" class="data row3 col2" >56.94</td>
#       <td id="T_21d43_row3_col3" class="data row3 col3" >6.81</td>
#       <td id="T_21d43_row3_col4" class="data row3 col4" >8.93</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21d43_row4_col0" class="data row4 col0" >3.20</td>
#       <td id="T_21d43_row4_col1" class="data row4 col1" >29.83</td>
#       <td id="T_21d43_row4_col2" class="data row4 col2" >57.85</td>
#       <td id="T_21d43_row4_col3" class="data row4 col3" >1.19</td>
#       <td id="T_21d43_row4_col4" class="data row4 col4" >7.94</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21d43_row5_col0" class="data row5 col0" >4.34</td>
#       <td id="T_21d43_row5_col1" class="data row5 col1" >26.71</td>
#       <td id="T_21d43_row5_col2" class="data row5 col2" >56.55</td>
#       <td id="T_21d43_row5_col3" class="data row5 col3" >1.34</td>
#       <td id="T_21d43_row5_col4" class="data row5 col4" >11.06</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21d43_row6_col0" class="data row6 col0" >1.17</td>
#       <td id="T_21d43_row6_col1" class="data row6 col1" >1.05</td>
#       <td id="T_21d43_row6_col2" class="data row6 col2" >94.87</td>
#       <td id="T_21d43_row6_col3" class="data row6 col3" >1.35</td>
#       <td id="T_21d43_row6_col4" class="data row6 col4" >1.56</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_21d43_row7_col0" class="data row7 col0" >0.21</td>
#       <td id="T_21d43_row7_col1" class="data row7 col1" >0.71</td>
#       <td id="T_21d43_row7_col2" class="data row7 col2" >30.41</td>
#       <td id="T_21d43_row7_col3" class="data row7 col3" >34.03</td>
#       <td id="T_21d43_row7_col4" class="data row7 col4" >34.64</td>
#     </tr>
#     <tr>
#       <th id="T_21d43_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_21d43_row8_col0" class="data row8 col0" >0

# %% [markdown]
# Here we can see the percentage of breakages in each location for a production month's period.

# %%
SUMNTL=NTL_print.sum()
#Column sums to be used for pie chart
SUMNTL

# %%
plt.rcParams["figure.figsize"] = (20,5)
names='DEPALLETIZER TO FILLER', 'FILLER TO CAPPER', 'CAPPER TO DUD DETECTOR', 'DUD DETECTOR TO LABELER', 'LABELER TO TRAYMAKER'
values=[34.08, 200.25, 885.83, 103.85, 175.97]
colors = ['#8EB897','#4F6272', '#B7C3F3', '#DD7596', '#cfd66f']
plt.pie(values, labels=names, labeldistance=1.15, wedgeprops = {'linewidth' : 3, 'edgecolor' : 'white'}, colors=colors);
plt.title('BREAKAGE AMOUNTS')
plt.show();
#Pie chart used to simply visually compare breakage amounts to someone not familiar with above line data

# %% [markdown]
# This chart shows that other than the Capper to Dud Detector (area's purpose is to kick out glass), the other two areas of focus are the Filler to Capper and Labeler to Traymaker. Visually these two areas look very similar in size.

# %% [markdown]
# ##Sankey Graph

# %%
CLEAN=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/Line%203%20bottle%20count%20record%20.xlsx%20-%20Sankey%20Clean.csv')

# %%
fig = go.Figure(data=[go.Sankey(
    node = dict(
      thickness = 5,
      line = dict(color = "green", width = 15),
      label = CLEAN.LABEL,
      color = "GREEN"
    ),
    link = dict(

      source = CLEAN.SOURCE,
      target = CLEAN.TARGET,
      value  = CLEAN.VALUE
  ))])

fig.show()
#Shows progression of loss through the line using total data from both March and April combined
#To be returned to when able to add data on speed and temp, need for this data has been addressed to company and is pending

# %% [markdown]
# As displayed we can see that the high breakage areas as recorded from March to April (a month of production) are the Dud Detector to Labeler, Filler to Capper, and Capper to Dud Detector. The Dud Detector is expected to have a high volume of removed bottles as it is actively kicking off any "duds" from the line. From the Filler to the Capper could possibly result from thermal shock as it is immediately after filling hot product into the bottle. After the Dud Detector to the Labeler is interesting because there is no easy assumption as to why this is. This is not a section that is in human contact, I would suggest maintaince investigating the line for signs of impact breakage.

# %% [markdown]
# #Breakage Analysis

# %% [markdown]
# Data provided by company glass supplier and limited for privacy. ONLY salvaged broken glass are used for analysis.

# %%
breakage=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/breakage.xlsx%20-%20Sheet2.csv')
breakage = breakage.rename(columns={'Months 2022':'MONTHS 2022'})
breakage.sort_values('MONTHS 2022',inplace=True) #aok more intuitive
breakage
#there are 4 types of glass breakages
#renamed for the sake of merge

# %%
breakage.plot(x='MONTHS 2022', y=['Stress Cracks','Impact Breakage','Spontaneous Breakage','Edge Damage'], kind='bar')
#breakage.plot.bar(figsize = (13,10))
plt.title('Cause of Breakage')
#the different breakages recorded throughout 2022

# %% [markdown]
# The primary cause of breakage has been stress cracks which are likely the result of thermal shock.
#
# The amount of stress cracks throughout the year vary in volume, this could be due to product demand and amount of production. Determining the cause of outlyers requires more investigation.
#
#
# It is also possible that because cause of breakages can only be investigated through salvaged glass that undocumented breakages could prove a different primary cause of breakages.

# %% [markdown]
# #Glass POs

# %%
CHGlass=pd.read_csv('https://raw.githubusercontent.com/khagerthey/VIS1/main/TOTAL%20SUM.csv')
CHGlass
#POs are product orders, below is the total amount of material ordered and recieved for each month

# %%
CHGlass = CHGlass.rename(columns={'TOTAL POS':'TOTAL PRODUCT RECEIVED'})
CHGlass = CHGlass.rename(columns={'MONTHS':'MONTHS 2022'})
CHGlass
#New header gives better descriptions

# %%
print(CHGlass.sum())

# %% [markdown]
# This are the total sum of glass ordered each month in 2022 with a grand total of 8554922 for the year. This is only glass used on line 3 which will be our main focus towards glass breakages.
# This data was retrieved from our inventroy database via Windows SL.

# %%
mergedbreakage = pd.merge(CHGlass, breakage, how='inner', on=['MONTHS 2022'], indicator='both')
mergedbreakage

# %%
mergedbreakage["TOTAL PRODUCT RECEIVED"] /=1000
mergedbreakage['TOTAL PRODUCT RECEIVED'] = mergedbreakage['TOTAL PRODUCT RECEIVED'].astype(float).round(1)
mergedbreakage

# %%
mergedbreakage.plot(x='MONTHS 2022', y=['TOTAL PRODUCT RECEIVED','Stress Cracks','Impact Breakage','Edge Damage'], kind='line', figsize=(10,8))
plt.title('Amount vs. Break')
#purpose of graph to show correlation of po to breakage
#TOTAL PRODUCT RECEIVED is shown in thousands

# %% [markdown]
# This graph displays glass breakage analysis provided from the company's glass distributor. The glass amounts are estimated based on paper records. As we can see the amount of stress cracks follow the total amount in trend while. Reported impact breakages are very low which is surprising when compared to the amount of locational breakages seen above after the filler.
#
# When addressed to the company, their reasoning for this is due to inconsistent documentation and lack of training.

# %% [markdown]
# #Conclusion

# %% [markdown]
# The company needs to reevaluate their training processes, especially in relation to documentation before drawing any certain conclusion. It is clear that there is inconsistent data. In addition, training on the line will likely reduce breakages due to human error and would be the most cost effective start to addressing the problem.
#
# Other alternative steps to take would be installing more sensors on all lines to compare breakages. Better data will allow for better analysis and thus more accurate conclusions.

# %% [markdown]
# **Next Steps**
#
# Compare data from all lines with added sensors -- may have common breakage locations
#
# Compare breakage amounts before and after training to determine amount of human error
#
# Record temperature changes throughout the line of glass and product to test thermal shock hypothesis
#
# Record line speed and compare other line speeds to see relation to breakages
